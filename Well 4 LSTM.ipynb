# %%
import pandas as pd
from pandas import Series
from pandas import read_csv
from pandas import concat
from pandas import DataFrame
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from math import sqrt
from matplotlib import pyplot as plt
import numpy 
# %matplotlib inline

# %%
df = read_csv('well_4_clean.csv')
series = Series(data = df['Oil Volume'])

# %%
def difference(dataset, interval=1):
    diff = list()
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return pd.Series(diff)

# %%
def timeseries_to_supervised(data, lag=1):
    df = DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df

# %%
def inverse_difference(history, yhat, interval=1):
    return yhat + history[-interval]

# %%
def scale(train, test):
    # fit scaler
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler = scaler.fit(train)
    # transform train
    train = train.reshape(train.shape[0], train.shape[1])
    train_scaled = scaler.transform(train)
    # transform test
    test = test.reshape(test.shape[0], test.shape[1])
    test_scaled = scaler.transform(test)
    return scaler, train_scaled, test_scaled

# %%
def invert_scale(scaler, X, value):
    new_row = [x for x in X] + [value]
    array = numpy.array(new_row)
    array = array.reshape(1, len(array))
    inverted = scaler.inverse_transform(array)
    return inverted[0, -1]

# %%
def forecast_lstm(model, batch_size, X):
    X = X.reshape(1, 1, len(X))
    yhat = model.predict(X, batch_size=batch_size)
    return yhat[0,0]

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
def fit_lstm(train, test, batch_size, nb_epoch, neurons):
    X, y = train[:, 0:-1], train[:, -1]
    X = X.reshape(X.shape[0], 1, X.shape[1])
    Val_X = test[:, 0]
    Val_X = Val_X.reshape((len(Val_X), 1, 1))
    Val_Y = test[:, 1]
    model = Sequential()
    model.add(LSTM(neurons, batch_input_shape=(batch_size, X.shape[1], X.shape[2]), stateful=True,return_sequences=False ))
    #second layer - make sure return_sequences=True to run this layer
    #model.add(LSTM(neurons, batch_input_shape=(batch_size, X.shape[1], X.shape[2]), stateful=True))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    for i in range(nb_epoch):
        model.fit(X, y, epochs=1, batch_size=batch_size, verbose=0, shuffle=False)
        model.reset_states()
    history = model.fit(X, y, epochs=nb_epoch, validation_data = (Val_X, Val_Y), shuffle = False, batch_size=batch_size)
    return model, history

# %%
#Get a dataset of differenced values to make stationary
raw_values = series.values
diff_values = difference(raw_values, 1)

# %%
#returns a dataset with the differenced dataset and a differenced dataset with a lag of 1
supervised = timeseries_to_supervised(diff_values, 1)
supervised_values = supervised.values

# %%
#split train and test data
split_fraction = .67
train_size = int(len(supervised_values) * split_fraction)
test_size = len(supervised_values) - train_size
train, test = supervised_values[0 : train_size,:], supervised_values[train_size:len(supervised_values),:]

# %%
#Scales the train and the test data
scaler, train_scaled, test_scaled = scale(train, test)

# %%
#split train and test for the history parameter
Val_X = test_scaled[:, 0]
Val_X = Val_X.reshape((len(Val_X), 1, 1))
Val_Y = test_scaled[:, 1]

trainX = train_scaled[:, 0]
trainX = trainX.reshape((len(trainX), 1, 1))
trainY = train_scaled[:, 1]

# %%
lstm_model, history = fit_lstm(train_scaled, test_scaled, 1, 100, 4)
# Out:
# Train on 933 samples, validate on 460 samples
# Epoch 1/100
# 933/933 [==============================] - 3s 3ms/step - loss: 0.0186 - val_loss: 0.0343
# Epoch 2/100
# 933/933 [==============================] - 2s 3ms/step - loss: 0.0186 - val_loss: 0.0342
# Epoch 3/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0186 - val_loss: 0.0342
# Epoch 4/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0186 - val_loss: 0.0342
# Epoch 5/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0186 - val_loss: 0.0343
# Epoch 6/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0186 - val_loss: 0.0343
# Epoch 7/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0186 - val_loss: 0.0343
# Epoch 8/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0186 - val_loss: 0.0343
# Epoch 9/100
# 933/933 [==============================] - 2s 3ms/step - loss: 0.0186 - val_loss: 0.0343
# Epoch 10/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0186 - val_loss: 0.0343
# Epoch 11/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0186 - val_loss: 0.0342
# Epoch 12/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0186 - val_loss: 0.0343
# Epoch 13/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0186 - val_loss: 0.0343
# Epoch 14/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0186 - val_loss: 0.0343
# Epoch 15/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0186 - val_loss: 0.0343
# Epoch 16/100
# 933/933 [==============================] - 2s 3ms/step - loss: 0.0186 - val_loss: 0.0343
# Epoch 17/100
# 933/933 [==============================] - 2s 3ms/step - loss: 0.0186 - val_loss: 0.0343
# Epoch 18/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0186 - val_loss: 0.0343
# Epoch 19/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0185 - val_loss: 0.0343
# Epoch 20/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0185 - val_loss: 0.0342
# Epoch 21/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0185 - val_loss: 0.0342
# Epoch 22/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0185 - val_loss: 0.0342
# Epoch 23/100
# 933/933 [==============================] - 2s 3ms/step - loss: 0.0185 - val_loss: 0.0342
# Epoch 24/100
# 933/933 [==============================] - 2s 3ms/step - loss: 0.0185 - val_loss: 0.0342
# Epoch 25/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0185 - val_loss: 0.0342
# Epoch 26/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0185 - val_loss: 0.0342
# Epoch 27/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0185 - val_loss: 0.0342
# Epoch 28/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0185 - val_loss: 0.0342
# Epoch 29/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0185 - val_loss: 0.0342
# Epoch 30/100
# 933/933 [==============================] - 2s 3ms/step - loss: 0.0185 - val_loss: 0.0342
# Epoch 31/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0186 - val_loss: 0.0343
# Epoch 32/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0186 - val_loss: 0.0342
# Epoch 33/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0185 - val_loss: 0.0342
# Epoch 34/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0185 - val_loss: 0.0342
# Epoch 35/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0185 - val_loss: 0.0342
# Epoch 36/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0185 - val_loss: 0.0342
# Epoch 37/100
# 933/933 [==============================] - 2s 3ms/step - loss: 0.0185 - val_loss: 0.0342
# Epoch 38/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0185 - val_loss: 0.0342
# Epoch 39/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0185 - val_loss: 0.0342
# Epoch 40/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0185 - val_loss: 0.0342
# Epoch 41/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0185 - val_loss: 0.0342
# Epoch 42/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0185 - val_loss: 0.0343
# Epoch 43/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0185 - val_loss: 0.0343
# Epoch 44/100
# 933/933 [==============================] - 3s 3ms/step - loss: 0.0185 - val_loss: 0.0343
# Epoch 45/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0185 - val_loss: 0.0343
# Epoch 46/100
# 933/933 [==============================] - 2s 3ms/step - loss: 0.0185 - val_loss: 0.0343
# Epoch 47/100
# 933/933 [==============================] - 3s 3ms/step - loss: 0.0185 - val_loss: 0.0343
# Epoch 48/100
# 933/933 [==============================] - 2s 3ms/step - loss: 0.0185 - val_loss: 0.0344
# Epoch 49/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0185 - val_loss: 0.0344
# Epoch 50/100
# 933/933 [==============================] - 2s 3ms/step - loss: 0.0185 - val_loss: 0.0344
# Epoch 51/100
# 933/933 [==============================] - 3s 3ms/step - loss: 0.0185 - val_loss: 0.0344
# Epoch 52/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0185 - val_loss: 0.0344
# Epoch 53/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0185 - val_loss: 0.0344
# Epoch 54/100
# 933/933 [==============================] - 2s 3ms/step - loss: 0.0185 - val_loss: 0.0345
# Epoch 55/100
# 933/933 [==============================] - 3s 3ms/step - loss: 0.0186 - val_loss: 0.0345
# Epoch 56/100
# 933/933 [==============================] - 3s 3ms/step - loss: 0.0186 - val_loss: 0.0345
# Epoch 57/100
# 933/933 [==============================] - 3s 3ms/step - loss: 0.0186 - val_loss: 0.0345
# Epoch 58/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0186 - val_loss: 0.0345
# Epoch 59/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0186 - val_loss: 0.0345
# Epoch 60/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0186 - val_loss: 0.0345
# Epoch 61/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0186 - val_loss: 0.0346
# Epoch 62/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0186 - val_loss: 0.0347
# Epoch 63/100
# 933/933 [==============================] - 3s 3ms/step - loss: 0.0186 - val_loss: 0.0347
# Epoch 64/100
# 933/933 [==============================] - 3s 4ms/step - loss: 0.0186 - val_loss: 0.0347
# Epoch 65/100
# 933/933 [==============================] - 2s 3ms/step - loss: 0.0186 - val_loss: 0.0347
# Epoch 66/100
# 933/933 [==============================] - 2s 3ms/step - loss: 0.0186 - val_loss: 0.0348
# Epoch 67/100
# 933/933 [==============================] - 2s 3ms/step - loss: 0.0186 - val_loss: 0.0348
# Epoch 68/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0186 - val_loss: 0.0348
# Epoch 69/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0186 - val_loss: 0.0348
# Epoch 70/100
# 933/933 [==============================] - 3s 3ms/step - loss: 0.0186 - val_loss: 0.0348
# Epoch 71/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0186 - val_loss: 0.0349
# Epoch 72/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0186 - val_loss: 0.0349
# Epoch 73/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0186 - val_loss: 0.0349
# Epoch 74/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0186 - val_loss: 0.0349
# Epoch 75/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0186 - val_loss: 0.0350
# Epoch 76/100
# 933/933 [==============================] - 2s 3ms/step - loss: 0.0186 - val_loss: 0.0350
# Epoch 77/100
# 933/933 [==============================] - 3s 3ms/step - loss: 0.0187 - val_loss: 0.0351
# Epoch 78/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0187 - val_loss: 0.0351
# Epoch 79/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0187 - val_loss: 0.0352
# Epoch 80/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0187 - val_loss: 0.0352
# Epoch 81/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0187 - val_loss: 0.0353
# Epoch 82/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0187 - val_loss: 0.0353
# Epoch 83/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0187 - val_loss: 0.0354
# Epoch 84/100
# 933/933 [==============================] - 2s 3ms/step - loss: 0.0187 - val_loss: 0.0354
# Epoch 85/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0187 - val_loss: 0.0355
# Epoch 86/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0187 - val_loss: 0.0356
# Epoch 87/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0187 - val_loss: 0.0357
# Epoch 88/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0187 - val_loss: 0.0358
# Epoch 89/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0187 - val_loss: 0.0359
# Epoch 90/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0187 - val_loss: 0.0360
# Epoch 91/100
# 933/933 [==============================] - 2s 3ms/step - loss: 0.0187 - val_loss: 0.0363
# Epoch 92/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0187 - val_loss: 0.0365
# Epoch 93/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0187 - val_loss: 0.0367
# Epoch 94/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0187 - val_loss: 0.0367
# Epoch 95/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0187 - val_loss: 0.0370
# Epoch 96/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0188 - val_loss: 0.0370
# Epoch 97/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0188 - val_loss: 0.0370
# Epoch 98/100
# 933/933 [==============================] - 2s 3ms/step - loss: 0.0188 - val_loss: 0.0371
# Epoch 99/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0188 - val_loss: 0.0376
# Epoch 100/100
# 933/933 [==============================] - 2s 2ms/step - loss: 0.0188 - val_loss: 0.0379

# %%
predictions = list()
for i in range(len(test_scaled)):
    # make one-step forecast
    X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
    yhat = forecast_lstm(lstm_model, 1, X)
    # invert scaling
    yhat = invert_scale(scaler, X, yhat)
    # invert differencing
    yhat = inverse_difference(raw_values, yhat, len(test_scaled)+1-i)
    # store forecast
    predictions.append(yhat)
    expected = raw_values[len(train) + i + 1]

# %%
train_predictions = list()
for i in range(len(train_scaled)):
    # make one-step forecast
    X, y = train_scaled[i, 0:-1], train_scaled[i, -1]
    yhat = forecast_lstm(lstm_model, 1, X)
    # invert scaling
    yhat = invert_scale(scaler, X, yhat)
    # invert differencing
    yhat = inverse_difference(raw_values, yhat, -i)
    # store forecast
    train_predictions.append(yhat)

# %%
rmse = sqrt(mean_squared_error(raw_values[train_size + 1:], predictions))
print('Test RMSE: %.3f' % rmse)

train_rmse = sqrt(mean_squared_error(raw_values[:train_size ], train_predictions))
print('Train RMSE: %.3f' % train_rmse)
# Out:
# Test RMSE: 254.114
# Train RMSE: 103.730

# %%
plt.plot(raw_values[train_size + 1:])
plt.plot(predictions, alpha = .6)

# %%
plt.plot(raw_values[:train_size ])
plt.plot(train_predictions, alpha = .6)

# %%
plt.plot(raw_values)
plt.plot(train_predictions)
plt.plot([None for x in train_predictions] + [x for x in predictions])

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model train vs validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
